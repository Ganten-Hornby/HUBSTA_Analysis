# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import matplotlib.colors as mcolors
plt.rcParams['pdf.fonttype'] = 42
from matplotlib.font_manager import fontManager, FontProperties
fontManager.addfont('/data/work/Arial.ttf')
font = FontProperties(fname='/data/work/Arial.ttf')
font_name = font.get_name()
plt.rcParams['font.family'] = font_name

# %%
names = [
    # 'B03607C4E6_WT2024071214941',
    
    '12_B03605F3G5_WT202403310048',
    '13_B03612A1C3_WT202403310056',
    '14_A03591A1C3_WT202403310045',
    '16_A03592A4C6_WT202403310044',
    '18_B03602C4D6_WT202405020031',
    '20_B03606F3G5_WT202405020032',
    '22_B03606C4E6_WT202403310050',
    '23_B03609A4D6_WT202404150263',
    '27_B03610C1E3_WT202403310051',
    '31_B03619A1D3_WT202403310052',
    '35_B03619E4G6_WT202403310053',
    '39_A03589A1D4_WT202403310046',
    '43_A03590E1G4_WT202403310064',
    '47_A03593C1F3_WT202403310068',
]
dic_dmt_leiden = {
    'hip_sc_1': 'hip_sc_01', 
    'hip_sc_2': 'hip_sc_02', 
    'hip_sc_3': 'hip_sc_03',
    'hip_sc_4': 'hip_sc_04',
    'hip_sc_5': 'hip_sc_05', 
    'hip_sc_6': 'hip_sc_06',
    'hip_sc_7': 'hip_sc_07', 
    'hip_sc_8': 'hip_sc_08', 
    'hip_sc_9': 'hip_sc_09', 
}
def lighten_color(hex_color, factor=0.5):
   
    rgb = mcolors.to_rgb(hex_color)
    
    new_rgb = [c + (1 - c) * factor for c in rgb]
    
    new_rgb = [min(c, 1.0) for c in new_rgb]
    
    return mcolors.to_hex(new_rgb)

# %%
# GW13
frames = []
for name in names:
    total_send_counter = Counter()
    total_receive_counter = Counter()
    path = f'/data/work/05.cluster/FuseMap/0116/cci/{name}.csv'
    ids,chip, task = name.split('_')
    csv = pd.read_csv(path)
    send = [dic_dmt_leiden[i.split('-')[0]] if i.split('-')[0] in dic_dmt_leiden.keys() else i.split('-')[0] for i in csv['sr_pair'].tolist()]
    receive = [dic_dmt_leiden[i.split('-')[1]] if i.split('-')[1] in dic_dmt_leiden.keys() else i.split('-')[1] for i in csv['sr_pair'].tolist()]
    
    send_counter = Counter(send)
    receive_counter = Counter(receive)
    
    total_send_counter += send_counter
    total_receive_counter += receive_counter
    
    send_frame = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'{ids}_send', f'{ids}_receive'], data = 0)
    for c in total_send_counter.keys():
        send_frame.loc[c][f'{ids}_send'] = total_send_counter[c]
    for c in total_receive_counter.keys():
        send_frame.loc[c][f'{ids}_receive'] = total_receive_counter[c]
    frames.append(send_frame)
frame = pd.concat(frames, axis = 1)
send_lis = [i for i in frame.columns if 'send' in i ]
receive_lis = [i  for i in frame.columns if 'receive' in i]
send_frame_GW13 = frame[send_lis] 
receive_frame_GW13 = frame[receive_lis]

# GW12
total_send_counter = Counter()
total_receive_counter = Counter()
path = f'/data/work/05.cluster/FuseMap/0116/cci/{name}.csv'
ids,chip, task = name.split('_')
csv = pd.read_csv(path)
send = [dic_dmt_leiden[i.split('-')[0]] if i.split('-')[0] in dic_dmt_leiden.keys() else i.split('-')[0] for i in csv['sr_pair'].tolist()]
receive = [dic_dmt_leiden[i.split('-')[1]] if i.split('-')[1] in dic_dmt_leiden.keys() else i.split('-')[1] for i in csv['sr_pair'].tolist()]

send_counter = Counter(send)
receive_counter = Counter(receive)

total_send_counter += send_counter
total_receive_counter += receive_counter

send_frame = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                               'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                               'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'send', f'receive'], data = 0)
for c in total_send_counter.keys():
    send_frame.loc[c][f'send'] = total_send_counter[c]
for c in total_receive_counter.keys():
    send_frame.loc[c][f'receive'] = total_receive_counter[c]



send_frame_two = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'GW12', f'GW13'], data = 0)
send_frame_two['GW13'] = send_frame_GW13.mean(axis = 1).to_list()
send_frame_two['GW12'] = send_frame['send'].to_list()


receive_frame_two = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'GW12', f'GW13'], data = 0)
receive_frame_two['GW13'] = receive_frame_GW13.mean(axis = 1).to_list()
receive_frame_two['GW12'] = send_frame['receive'].to_list()

# %%
colors1 = ['#9b38e9', '#a89630', '#5b798b', '#cb2505', '#62e7dd', '#245200', '#374898', '#6d85c7', '#35c498', '#9e2dc6', '#2d7476', '#cb0d6c', '#20ea38', '#0fabb6', '#a59099', '#2bea3a', '#17b064', '#52b8d5', '#da2ef2', '#6240f7', '#c47233', '#a83b23', '#9994da']
colors2 = ['#cd9cf4', '#d3cb98', '#adbcc5', '#e59282', '#b0f3ee', '#92a980', '#9ba3cc', '#b6c2e3', '#9ae2cc', '#ce96e2', '#96babb', '#e586b5', '#90f49c', '#87d5db', '#d2c8cc', '#95f49c', '#8bd8b2', '#a9dcea', '#ec96f8', '#b0a0fb', '#e2b999', '#d39d91', '#cccaec']
categories = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'] 

GW12 = receive_frame_two['GW12'].tolist()
GW13 = receive_frame_two['GW13'].tolist()
x = np.arange(len(categories))
bar_width = 0.35 

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, color=colors2,
               # edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, color=colors1,
               # edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/receive_Colors.pdf', bbox_inches = 'tight')
plt.close()


fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               # color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               # color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/receive_BiColors.pdf', bbox_inches = 'tight')
plt.close()

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/receive_ColorsBiFrame.pdf', bbox_inches = 'tight')
plt.close()

# %%
colors1 = ['#9b38e9', '#a89630', '#5b798b', '#cb2505', '#62e7dd', '#245200', '#374898', '#6d85c7', '#35c498', '#9e2dc6', '#2d7476', '#cb0d6c', '#20ea38', '#0fabb6', '#a59099', '#2bea3a', '#17b064', '#52b8d5', '#da2ef2', '#6240f7', '#c47233', '#a83b23', '#9994da']
colors2 = ['#cd9cf4', '#d3cb98', '#adbcc5', '#e59282', '#b0f3ee', '#92a980', '#9ba3cc', '#b6c2e3', '#9ae2cc', '#ce96e2', '#96babb', '#e586b5', '#90f49c', '#87d5db', '#d2c8cc', '#95f49c', '#8bd8b2', '#a9dcea', '#ec96f8', '#b0a0fb', '#e2b999', '#d39d91', '#cccaec']
categories = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'] 

GW12 = send_frame_two['GW12'].tolist()
GW13 = send_frame_two['GW13'].tolist()
x = np.arange(len(categories))
bar_width = 0.35 

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, color=colors2,
               # edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, color=colors1,
               # edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/send_Colors.pdf', bbox_inches = 'tight')
plt.close()


fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               # color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               # color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/send_BiColors.pdf', bbox_inches = 'tight')
plt.close()

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/mean/send_ColorsBiFrame.pdf', bbox_inches = 'tight')
plt.close()

# %%
# GW13
frames = []
for name in names:
    total_send_counter = Counter()
    total_receive_counter = Counter()
    path = f'/data/work/05.cluster/FuseMap/0116/cci/{name}.csv'
    ids,chip, task = name.split('_')
    csv = pd.read_csv(path)
    send = [dic_dmt_leiden[i.split('-')[0]] if i.split('-')[0] in dic_dmt_leiden.keys() else i.split('-')[0] for i in csv['sr_pair'].tolist()]
    receive = [dic_dmt_leiden[i.split('-')[1]] if i.split('-')[1] in dic_dmt_leiden.keys() else i.split('-')[1] for i in csv['sr_pair'].tolist()]
    
    send_counter = Counter(send)
    receive_counter = Counter(receive)
    
    total_send_counter += send_counter
    total_receive_counter += receive_counter
    
    send_frame = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'{ids}_send', f'{ids}_receive'], data = 0)
    for c in total_send_counter.keys():
        send_frame.loc[c][f'{ids}_send'] = total_send_counter[c]
    for c in total_receive_counter.keys():
        send_frame.loc[c][f'{ids}_receive'] = total_receive_counter[c]
    frames.append(send_frame)
frame = pd.concat(frames, axis = 1)
send_lis = [i for i in frame.columns if 'send' in i ]
receive_lis = [i  for i in frame.columns if 'receive' in i]
send_frame_GW13 = frame[send_lis] 
receive_frame_GW13 = frame[receive_lis]

# GW12
total_send_counter = Counter()
total_receive_counter = Counter()
path = f'/data/work/05.cluster/FuseMap/0116/cci/{name}.csv'
ids,chip, task = name.split('_')
csv = pd.read_csv(path)
send = [dic_dmt_leiden[i.split('-')[0]] if i.split('-')[0] in dic_dmt_leiden.keys() else i.split('-')[0] for i in csv['sr_pair'].tolist()]
receive = [dic_dmt_leiden[i.split('-')[1]] if i.split('-')[1] in dic_dmt_leiden.keys() else i.split('-')[1] for i in csv['sr_pair'].tolist()]

send_counter = Counter(send)
receive_counter = Counter(receive)

total_send_counter += send_counter
total_receive_counter += receive_counter

send_frame = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                               'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                               'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'send', f'receive'], data = 0)
for c in total_send_counter.keys():
    send_frame.loc[c][f'send'] = total_send_counter[c]
for c in total_receive_counter.keys():
    send_frame.loc[c][f'receive'] = total_receive_counter[c]



send_frame_two = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'GW12', f'GW13'], data = 0)
send_frame_two['GW13'] = send_frame_GW13.median(axis = 1).to_list()
send_frame_two['GW12'] = send_frame['send'].to_list()


receive_frame_two = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], columns = [f'GW12', f'GW13'], data = 0)
receive_frame_two['GW13'] = receive_frame_GW13.median(axis = 1).to_list()
receive_frame_two['GW12'] = send_frame['receive'].to_list()

# %%
colors1 = ['#9b38e9', '#a89630', '#5b798b', '#cb2505', '#62e7dd', '#245200', '#374898', '#6d85c7', '#35c498', '#9e2dc6', '#2d7476', '#cb0d6c', '#20ea38', '#0fabb6', '#a59099', '#2bea3a', '#17b064', '#52b8d5', '#da2ef2', '#6240f7', '#c47233', '#a83b23', '#9994da']
colors2 = ['#cd9cf4', '#d3cb98', '#adbcc5', '#e59282', '#b0f3ee', '#92a980', '#9ba3cc', '#b6c2e3', '#9ae2cc', '#ce96e2', '#96babb', '#e586b5', '#90f49c', '#87d5db', '#d2c8cc', '#95f49c', '#8bd8b2', '#a9dcea', '#ec96f8', '#b0a0fb', '#e2b999', '#d39d91', '#cccaec']
categories = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'] 

GW12 = receive_frame_two['GW12'].tolist()
GW13 = receive_frame_two['GW13'].tolist()
x = np.arange(len(categories))
bar_width = 0.35 

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, color=colors2,
               # edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, color=colors1,
               # edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/receive_Colors.pdf', bbox_inches = 'tight')
plt.close()


fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               # color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               # color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/receive_BiColors.pdf', bbox_inches = 'tight')
plt.close()

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/receive_ColorsBiFrame.pdf', bbox_inches = 'tight')
plt.close()

colors1 = ['#9b38e9', '#a89630', '#5b798b', '#cb2505', '#62e7dd', '#245200', '#374898', '#6d85c7', '#35c498', '#9e2dc6', '#2d7476', '#cb0d6c', '#20ea38', '#0fabb6', '#a59099', '#2bea3a', '#17b064', '#52b8d5', '#da2ef2', '#6240f7', '#c47233', '#a83b23', '#9994da']
colors2 = ['#cd9cf4', '#d3cb98', '#adbcc5', '#e59282', '#b0f3ee', '#92a980', '#9ba3cc', '#b6c2e3', '#9ae2cc', '#ce96e2', '#96babb', '#e586b5', '#90f49c', '#87d5db', '#d2c8cc', '#95f49c', '#8bd8b2', '#a9dcea', '#ec96f8', '#b0a0fb', '#e2b999', '#d39d91', '#cccaec']
categories = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'] 

GW12 = send_frame_two['GW12'].tolist()
GW13 = send_frame_two['GW13'].tolist()
x = np.arange(len(categories))
bar_width = 0.35 

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, color=colors2,
               # edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, color=colors1,
               # edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/send_Colors.pdf', bbox_inches = 'tight')
plt.close()


fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               # color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               # color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/send_BiColors.pdf', bbox_inches = 'tight')
plt.close()

fig, ax = plt.subplots(figsize=(12, 3))

bars1 = ax.bar(x - bar_width / 2, GW12, width=bar_width, 
               color=colors2,
               edgecolor='#3274A1', 
               linewidth=2, label='GW12')

bars2 = ax.bar(x + bar_width / 2, GW13, width=bar_width, 
               color=colors1,
               edgecolor='#E1812C', 
               linewidth=2, label='GW13.5')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation = 45,ha = 'right')
ax.legend()
plt.savefig('/data/work/05.cluster/FuseMap/0116/cci/median/send_ColorsBiFrame.pdf', bbox_inches = 'tight')
plt.close()

# %%
names = [
    'B03607C4E6_WT2024071214941',
    
    '12_B03605F3G5_WT202403310048',
    '13_B03612A1C3_WT202403310056',
    '14_A03591A1C3_WT202403310045',
    '16_A03592A4C6_WT202403310044',
    '18_B03602C4D6_WT202405020031',
    '20_B03606F3G5_WT202405020032',
    '22_B03606C4E6_WT202403310050',
    '23_B03609A4D6_WT202404150263',
    '27_B03610C1E3_WT202403310051',
    '31_B03619A1D3_WT202403310052',
    '35_B03619E4G6_WT202403310053',
    '39_A03589A1D4_WT202403310046',
    '43_A03590E1G4_WT202403310064',
    '47_A03593C1F3_WT202403310068',
]
dataframes = []
for name in names:
    total_send_counter = Counter()
    total_receive_counter = Counter()
    path = f'/data/work/05.cluster/FuseMap/0116/cci/{name}.csv'
    # ids,chip, task = name.split('_')
    csv = pd.read_csv(path)

    
    heatmap = pd.DataFrame(index = ['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], 
                           columns =['hip_sc_01', 'hip_sc_02', 'hip_sc_03', 'hip_sc_04', 'hip_sc_05', 'hip_sc_06', 'hip_sc_07', 'hip_sc_08', 'hip_sc_09', 
                                   'hip_sc_10', 'hip_sc_11', 'hip_sc_12', 'hip_sc_13', 'hip_sc_14', 'hip_sc_15', 'hip_sc_16', 'hip_sc_17', 'hip_sc_18', 
                                   'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'], data = 0)
    for i in csv['sr_pair'].tolist():
        send = i.split('-')[0]
        send = dic_dmt_leiden[send] if send in dic_dmt_leiden.keys() else send
        recive = i.split('-')[1]
        recive = dic_dmt_leiden[recive] if recive in dic_dmt_leiden.keys() else recive
        heatmap[send][recive] += 1
    import seaborn as sns
    sns.heatmap(heatmap, cmap = 'Reds')
    plt.xlabel('Send')
    plt.ylabel('Receive')
    plt.savefig(f'/data/work/05.cluster/FuseMap/0116/cci/heatmap/{name}.pdf', bbox_inches = 'tight')
    
    plt.close()
    dataframes.append(heatmap)

dataframes = dataframes[1:]
stacked_data = np.array([df.values for df in dataframes])

mean_result = pd.DataFrame(
    stacked_data.mean(axis=0),  # 沿第一个轴（axis=0）求均值
    index=dataframes[0].index,
    columns=dataframes[0].columns
)
sns.heatmap(mean_result, cmap = 'Reds')
plt.xlabel('Send')
plt.ylabel('Receive')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/cci/heatmap/GW13_MEAN.pdf', bbox_inches = 'tight')

plt.close()


median_result = pd.DataFrame(
    np.median(stacked_data, axis=0),  # 沿第一个轴（axis=0）求中位数
    index=dataframes[0].index,
    columns=dataframes[0].columns
)

sns.heatmap(median_result, cmap = 'Reds')
plt.xlabel('Send')
plt.ylabel('Receive')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/cci/heatmap/GW13_MEDIAN.pdf', bbox_inches = 'tight')

plt.close()

# %%
heatmap
# Out:
#            hip_sc_01  hip_sc_02  hip_sc_03  hip_sc_04  hip_sc_05  hip_sc_06  \
# hip_sc_01          0          1          0          0          0          0
# hip_sc_02          1          0          0          0          0          0
# hip_sc_03          2          0          0          0          2          0
# hip_sc_04          0          0          0          0          0          0
# hip_sc_05          0          0          3          0          0          0
# hip_sc_06          0          0          0          0          0          0
# hip_sc_07          0          0          0          0          0          0
# hip_sc_08          0          0          0          0          1          0
# hip_sc_09          0          0          0          0          0          0
# hip_sc_10          0          0          0          0          0          0
# hip_sc_11          0          0          0          0          0          0
# ...

# %%
heatmap['hip_sc_03']['hip_sc_01']
# Out:
# 0
