# %%
library(Seurat)
library(tidyverse)
library(here)
library(cowplot)
library(ggridges)
library(colorspace)
`%ni%` = Negate(`%in%`)
# Out:
# Attaching SeuratObject
#
# Warning message in system("timedatectl", intern = TRUE):
# "running command 'timedatectl' had status 1"
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.4.0     v purrr   1.0.2
# v tibble  3.2.1     v dplyr   1.1.4
# v tidyr   1.3.1     v stringr 1.5.1
# v readr   2.1.3     v forcats 0.5.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# here() starts at /data/work/05.cluster/FuseMap/0116

# %%
# 假设 data 是你的数据框
library(ggplot2)
library(ggridges)

# 定义 colormap
colormap = c(
  'hip_sc_01' = '#9b38e9',
  'hip_sc_02' = '#a89630',
  'hip_sc_03'= '#5b798b',
  'hip_sc_04' = '#cb2505',
  'hip_sc_05' = '#62e7dd',
  'hip_sc_06' = '#245200',
  'hip_sc_07' = '#374898',
  'hip_sc_08' = '#6d85c7',
  'hip_sc_09' = '#35c498',
  'hip_sc_10' = '#9e2dc6',
  'hip_sc_11' = '#2d7476',
  'hip_sc_12' = '#cb0d6c',
  'hip_sc_13' = '#20ea38',
  'hip_sc_14' = '#0fabb6',
  'hip_sc_15' = '#a59099',
  'hip_sc_16' = '#2bea3a',
  'hip_sc_17' = '#17b064',
  'hip_sc_18' = '#52b8d5',
  'hip_sc_19' = '#da2ef2',
  'hip_sc_20' = '#6240f7',
  'hip_sc_21' = '#c47233',
  'hip_sc_22'='#a83b23',
  'hip_sc_23'='#9994da'
)
colormap = c(
    'ctx_sc_01' = '#374898',
  'ctx_sc_02' = '#6d85c7',
  'ctx_sc_03' = '#35c498',
  'ctx_sc_04' = '#9e2dc6',
  'ctx_sc_05' = '#2d7476',
  'ctx_sc_06' = '#cb0d6c',
  'ctx_sc_07' = '#20ea38',
  'ctx_sc_08' = '#0fabb6',
  'ctx_sc_09' = '#a59099',
  'ctx_sc_10' = '#2bea3a',
  'ctx_sc_11' = '#17b064',
  'ctx_sc_12' = '#52b8d5',
  'ctx_sc_13' = '#da2ef2',
  'ctx_sc_14' = '#6240f7',
  'ctx_sc_15' = '#c47233',
  'ctx_sc_16' = '#a83b23',
  'ctx_sc_17' = '#9994da',
  'hip_sc_18' = '#9b38e9',
  'hip_sc_19' = '#a89630',
  'hip_sc_20' = '#5b798b',
  'hip_sc_21' = '#cb2505',
  'hip_sc_22' = '#62e7dd',
  'hip_sc_23' = '#245200'

)

# %%
colormap = c(
    'ctx_sc_01_GW12' = '#374898',
  'ctx_sc_02_GW12' = '#6d85c7',
  'ctx_sc_03_GW12' = '#35c498',
  'ctx_sc_04_GW12' = '#9e2dc6',
  'ctx_sc_05_GW12' = '#2d7476',
  'ctx_sc_06_GW12' = '#cb0d6c',
  'ctx_sc_07_GW12' = '#20ea38',
  'ctx_sc_08_GW12' = '#0fabb6',
  'ctx_sc_09_GW12' = '#a59099',
  'ctx_sc_10_GW12' = '#2bea3a',
  'ctx_sc_11_GW12' = '#17b064',
  'ctx_sc_12_GW12' = '#52b8d5',
  'ctx_sc_13_GW12' = '#da2ef2',
  'ctx_sc_14_GW12' = '#6240f7',
  'ctx_sc_15_GW12' = '#c47233',
  'ctx_sc_16_GW12' = '#a83b23',
  'ctx_sc_17_GW12' = '#9994da',
  'hip_sc_18_GW12' = '#9b38e9',
  'hip_sc_19_GW12' = '#a89630',
  'hip_sc_20_GW12' = '#5b798b',
  'hip_sc_21_GW12' = '#cb2505',
  'hip_sc_22_GW12' = '#62e7dd',
  'hip_sc_23_GW12' = '#245200',
    
'ctx_sc_01_GW13' = '#374898',
  'ctx_sc_02_GW13' = '#6d85c7',
  'ctx_sc_03_GW13' = '#35c498',
  'ctx_sc_04_GW13' = '#9e2dc6',
  'ctx_sc_05_GW13' = '#2d7476',
  'ctx_sc_06_GW13' = '#cb0d6c',
  'ctx_sc_07_GW13' = '#20ea38',
  'ctx_sc_08_GW13' = '#0fabb6',
  'ctx_sc_09_GW13' = '#a59099',
  'ctx_sc_10_GW13' = '#2bea3a',
  'ctx_sc_11_GW13' = '#17b064',
  'ctx_sc_12_GW13' = '#52b8d5',
  'ctx_sc_13_GW13' = '#da2ef2',
  'ctx_sc_14_GW13' = '#6240f7',
  'ctx_sc_15_GW13' = '#c47233',
  'ctx_sc_16_GW13' = '#a83b23',
  'ctx_sc_17_GW13' = '#9994da',
  'hip_sc_18_GW13' = '#9b38e9',
  'hip_sc_19_GW13' = '#a89630',
  'hip_sc_20_GW13' = '#5b798b',
  'hip_sc_21_GW13' = '#cb2505',
  'hip_sc_22_GW13' = '#62e7dd',
  'hip_sc_23_GW13' = '#245200'
)
# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/gw12_gw13.csv")
filtered_data <- data %>% filter(dmt_leiden_anno_gw != "z_delete")
filtered_data$dmt_leiden_anno_gw = factor(filtered_data$dmt_leiden_anno_gw, levels = c(
 'hip_sc_23_GW13',
 'hip_sc_23_GW12',
 'hip_sc_22_GW13',
 'hip_sc_22_GW12',
 'hip_sc_21_GW13',
 'hip_sc_21_GW12',
 'hip_sc_20_GW13',
 'hip_sc_20_GW12',
 'hip_sc_19_GW13',
 'hip_sc_19_GW12',
 'hip_sc_18_GW13',
 'hip_sc_18_GW12',
 'ctx_sc_17_GW13',
 'ctx_sc_17_GW12',
 'ctx_sc_16_GW13',
 'ctx_sc_16_GW12',
 'ctx_sc_15_GW13',
 'ctx_sc_15_GW12',
 'ctx_sc_14_GW13',
 'ctx_sc_14_GW12',
 'ctx_sc_13_GW13',
 'ctx_sc_13_GW12',
 'ctx_sc_12_GW13',
 'ctx_sc_12_GW12',
 'ctx_sc_11_GW13',
 'ctx_sc_11_GW12',
 'ctx_sc_10_GW13',
 'ctx_sc_10_GW12',
 'ctx_sc_09_GW13',
 'ctx_sc_09_GW12',
 'ctx_sc_08_GW13',
 'ctx_sc_08_GW12',
 'ctx_sc_07_GW13',
 'ctx_sc_07_GW12',
 'ctx_sc_06_GW13',
 'ctx_sc_06_GW12',
 'ctx_sc_05_GW13',
 'ctx_sc_05_GW12',
 'ctx_sc_04_GW13',
 'ctx_sc_04_GW12',
 'ctx_sc_03_GW13',
 'ctx_sc_03_GW12',
 'ctx_sc_02_GW13',
 'ctx_sc_02_GW12',
 'ctx_sc_01_GW13',
 'ctx_sc_01_GW12'))
# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_column, y = dmt_leiden_anno_gw, fill = dmt_leiden_anno_gw)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/gw12_gw13_column.pdf")
print(p)
dev.off()
# Out:
# Picking joint bandwidth of 4.3
# png
#   2

# %%
# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))
# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_column, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064_column.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064_layer.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data <- filtered_data %>% filter(digital_column > 50)
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064_layer_allocortex.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data <- filtered_data %>% filter(digital_column < 50)
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1

pdf("/data/work/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064_layer_neocortex.pdf")
print(p)
dev.off()
# Out:
# Picking joint bandwidth of 4.04
# png
#   2
# Picking joint bandwidth of 3.63
# png
#   2
# Picking joint bandwidth of 3.75
# png
#   2
# Picking joint bandwidth of 5.33
# png
#   2

# %%
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

p <- filtered_data %>%
  ggplot(aes(x = digital_column, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941_column.pdf")
print(p)
dev.off()

data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941_layer.pdf")
print(p)
dev.off()


data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data <- filtered_data %>% filter(digital_column > 50)
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941_layer_allocortex.pdf")
print(p)
dev.off()


data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_anno != "z_delete")
filtered_data <- filtered_data %>% filter(digital_column < 50)
filtered_data$dmt_leiden_anno = factor(filtered_data$dmt_leiden_anno, levels = c('ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_anno, fill = dmt_leiden_anno)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941_layer_neocortex.pdf")
print(p)
dev.off()
# Out:
# Picking joint bandwidth of 4.57
# png
#   2
# Picking joint bandwidth of 4.24
# png
#   2
# Picking joint bandwidth of 4.79
# png
#   2
# Picking joint bandwidth of 5.66
# png
#   2

# %%
# colormap = c('hip_1' = '#e87bb8',
#  'hip_8' = '#7e14c2',
#  'hip_3' = '#efe245',
#  'hip_5' = '#ff9186',
#  'hip_4' = '#e1e0b7',
#  'hip_9' = '#466e1e',
#  'hip_0' = '#cdec1d',
#  'hip_12' = '#931757',
#  'NA' = '#553b12',
#  'hip_11' = '#17b1e4',
#  'hip_7' = '#507d87',
#  'hip_2' = '#d33d03')
colormap = c(
    'Hip0_COLA4A1_vessel'= '#cdec1d',
    'Hip1_ZBTB20_PCDH20_allo1'= '#e87bb8',
     'Hip2_PPP1R17_ELMO3_SVZ'= '#d33d03',
 'Hip3_NTS_allo2'= '#efe245',
 'Hip4_AC144831.1'= '#e1e0b7',
 'Hip5_POU3F1_IZ'= '#ff9186',
 'Hip6_COL4A1_vessel'= '#553b12',
 'Hip7_WNT7B_GPR22_CP&SP'= '#507d87',
 'Hip8_HOPX_FABP7_VZ'='#466e1e',
 'Hip9_PPP1R17_EOMES_SVZ'= '#931757',
    'Hip10_COL4A1_vessel'= '#E65100'
)

# %%
# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_column, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064_column.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064_layer.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data <- filtered_data %>% filter(digital_column > 50)
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064_layer_allocortex.pdf")
print(p)
dev.off()

# 读取CSV文件
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data <- filtered_data %>% filter(digital_column < 50)
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

# 绘制图形
p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1

pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/43_A03590E1G4_WT202403310064_layer_neocortex.pdf")
print(p)
dev.off()
# Out:
# Picking joint bandwidth of 4.04
# png
#   2
# Picking joint bandwidth of 2.82
# png
#   2
# Picking joint bandwidth of 2.94
# png
#   2
# Picking joint bandwidth of 3.15
# png
#   2

# %%
data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

p <- filtered_data %>%
  ggplot(aes(x = digital_column, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941_column.pdf")
print(p)
dev.off()

data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941_layer.pdf")
print(p)
dev.off()


data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data <- filtered_data %>% filter(digital_column > 50)
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941_layer_allocortex.pdf")
print(p)
dev.off()


data <- read.csv("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941.csv")
filtered_data <- data %>% filter(dmt_leiden_merge_spatial != "NA")
filtered_data <- filtered_data %>% filter(digital_column < 50)
filtered_data$dmt_leiden_merge_spatial = factor(filtered_data$dmt_leiden_merge_spatial, levels = c('Hip0_COLA4A1_vessel','Hip1_ZBTB20_PCDH20_allo1', 'Hip2_PPP1R17_ELMO3_SVZ', 'Hip3_NTS_allo2', 'Hip4_AC144831.1', 'Hip5_POU3F1_IZ', 'Hip6_COL4A1_vessel', 'Hip7_WNT7B_GPR22_CP&SP', 'Hip8_HOPX_FABP7_VZ', 'Hip9_PPP1R17_EOMES_SVZ', 'Hip10_COL4A1_vessel'))

p <- filtered_data %>%
  ggplot(aes(x = digital_layer, y = dmt_leiden_merge_spatial, fill = dmt_leiden_merge_spatial)) +
  scale_fill_manual(values = colormap) +  # 使用 colormap 映射颜色
  theme_bw() +
  xlab("") + ylab("") +
  theme(panel.grid = element_blank()) +
  theme(panel.border = element_blank()) +
  theme(axis.line = element_line(colour = "black")) +
  theme(legend.position = "none") +
  theme(axis.text = element_text(colour = "black")) +
  ggridges::geom_density_ridges(alpha = 0.8)+
  coord_fixed(ratio = 10)  # 设置长宽比例为 1:1
pdf("/data/work/05.cluster/FuseMap/0116/digital/spatial/B03607C4E6_WT2024071214941_layer_neocortex.pdf")
print(p)
dev.off()
# Out:
# Picking joint bandwidth of 4.05
# png
#   2
# Picking joint bandwidth of 3.69
# png
#   2
# Picking joint bandwidth of 4.9
# png
#   2
# Picking joint bandwidth of 5.26
# png
#   2

# %%
1
# Out:
# [1] 1
