# %%
import spaTrack as spt
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt

sc.settings.verbosity = 0

# %%
adata2 = sc.read_h5ad('/data/users/zhoutao3/online/05.cluster/FuseMap/0116/digital/single/B03607C4E6_WT2024071214941.h5ad')
dic_dmt_leiden = {
    '2': 'ctx_sc_01',
    '13': 'ctx_sc_02',
    '19': 'ctx_sc_03',
    '20': 'ctx_sc_04',
    
    '4': 'ctx_sc_05',
    '21': 'ctx_sc_05',
    
    '8': 'ctx_sc_06',
    '10': 'ctx_sc_07',
    '22': 'ctx_sc_08',
    
    '9': 'ctx_sc_09',
    '11': 'ctx_sc_09',
    '16': 'ctx_sc_10',
    '18': 'ctx_sc_10',
    '26': 'ctx_sc_10',
    '31': 'ctx_sc_10',
    
    '12': 'ctx_sc_11',
    '15': 'ctx_sc_12',
    '25': 'ctx_sc_12',
    '29': 'ctx_sc_12',
    '17': 'ctx_sc_13',
    
    '24': 'z_delete',
    
    
    '5': 'ctx_sc_14',
    '23': 'ctx_sc_15',
    '27': 'ctx_sc_16',
    
    '30': 'ctx_sc_17',
    
     '0': 'hip_sc_18',
    '7': 'hip_sc_19',
    
    '1': 'hip_sc_20',
    '3': 'hip_sc_21',
    '6': 'hip_sc_21',
    '14': 'hip_sc_22',
    '28': 'hip_sc_23',
}
adata2.obs['dmt_leiden_anno'] = [dic_dmt_leiden[i] for i in adata2.obs['dmt_leiden']]
adata2 = adata2[adata2.obs['dmt_leiden_anno'] != 'z_delete'].copy()
sc.pp.filter_genes(adata2, min_cells=10)
sc.pp.normalize_total(adata2, target_sum=1e4)
sc.pp.log1p(adata2)
colormap = {
   'ctx_sc_01' : '#374898',
  'ctx_sc_02' : '#6d85c7',
  'ctx_sc_03' : '#35c498',
  'ctx_sc_04' : '#9e2dc6',
  'ctx_sc_05' : '#2d7476',
  'ctx_sc_06' : '#cb0d6c',
  'ctx_sc_07' : '#20ea38',
  'ctx_sc_08' : '#0fabb6',
  'ctx_sc_09' : '#a59099',
  'ctx_sc_10' : '#2bea3a',
  'ctx_sc_11' : '#17b064',
  'ctx_sc_12' : '#52b8d5',
  'ctx_sc_13' : '#da2ef2',
  'ctx_sc_14' : '#6240f7',
  'ctx_sc_15' : '#c47233',
  'ctx_sc_16':'#a83b23',
  'ctx_sc_17':'#9994da',
  'hip_sc_18' : '#9b38e9',
  'hip_sc_19' : '#a89630',
  'hip_sc_20': '#5b798b',
  'hip_sc_21' : '#cb2505',
  'hip_sc_22' : '#62e7dd',
  'hip_sc_23' : '#245200',
}

# %%
adata1 = sc.read_h5ad('/data/users/zhoutao3/online/05.cluster/FuseMap/0116/digital/single/43_A03590E1G4_WT202403310064.h5ad')
dic_dmt_leiden = {
    '2': 'ctx_sc_01',
    '13': 'ctx_sc_02',
    '19': 'ctx_sc_03',
    '20': 'ctx_sc_04',
    
    '4': 'ctx_sc_05',
    '21': 'ctx_sc_05',
    
    '8': 'ctx_sc_06',
    '10': 'ctx_sc_07',
    '22': 'ctx_sc_08',
    
    '9': 'ctx_sc_09',
    '11': 'ctx_sc_09',
    '16': 'ctx_sc_10',
    '18': 'ctx_sc_10',
    '26': 'ctx_sc_10',
    '31': 'ctx_sc_10',
    
    '12': 'ctx_sc_11',
    '15': 'ctx_sc_12',
    '25': 'ctx_sc_12',
    '29': 'ctx_sc_12',
    '17': 'ctx_sc_13',
    
    '24': 'z_delete',
    
    
    '5': 'ctx_sc_14',
    '23': 'ctx_sc_15',
    '27': 'ctx_sc_16',
    
    '30': 'ctx_sc_17',
    
     '0': 'hip_sc_18',
    '7': 'hip_sc_19',
    
    '1': 'hip_sc_20',
    '3': 'hip_sc_21',
    '6': 'hip_sc_21',
    '14': 'hip_sc_22',
    '28': 'hip_sc_23',
}
adata1.obs['dmt_leiden_anno'] = [dic_dmt_leiden[i] for i in adata1.obs['dmt_leiden']]
adata1 = adata1[adata1.obs['dmt_leiden_anno'] != 'z_delete'].copy()
sc.pp.filter_genes(adata1, min_cells=10)
sc.pp.normalize_total(adata1, target_sum=1e4)
sc.pp.log1p(adata1)
colormap = {
   'ctx_sc_01' : '#374898',
  'ctx_sc_02' : '#6d85c7',
  'ctx_sc_03' : '#35c498',
  'ctx_sc_04' : '#9e2dc6',
  'ctx_sc_05' : '#2d7476',
  'ctx_sc_06' : '#cb0d6c',
  'ctx_sc_07' : '#20ea38',
  'ctx_sc_08' : '#0fabb6',
  'ctx_sc_09' : '#a59099',
  'ctx_sc_10' : '#2bea3a',
  'ctx_sc_11' : '#17b064',
  'ctx_sc_12' : '#52b8d5',
  'ctx_sc_13' : '#da2ef2',
  'ctx_sc_14' : '#6240f7',
  'ctx_sc_15' : '#c47233',
  'ctx_sc_16':'#a83b23',
  'ctx_sc_17':'#9994da',
  'hip_sc_18' : '#9b38e9',
  'hip_sc_19' : '#a89630',
  'hip_sc_20': '#5b798b',
  'hip_sc_21' : '#cb2505',
  'hip_sc_22' : '#62e7dd',
  'hip_sc_23' : '#245200',
}

# %%
adata2.obs['stage'] = 'GW12'
adata1.obs['stage'] = 'GW13.5'

# %%
import anndata as ad

# %%
adata = ad.concat([adata2, adata1])

# %%
import os
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import entropy
import seaborn as sns
import warnings
from IPython.display import display

def assess_start_cluster(adata, obs_key):
    cluster_name_list=list()
    entropy_list=list()
    cell_name_list=list()
    from scipy.sparse import issparse

    if issparse(adata.X):
        adata.X = adata.X.toarray()
    for i in range(0,len(adata.obs.index)):
        cell_id=adata.obs.index[i]
        cluster_name=adata.obs[obs_key][i]
        adata_cluster=adata[adata.obs.index.isin([cell_id])]
        matrix = np.array(adata_cluster.X)
        entropy_name=entropy(matrix[0])
        cluster_name_list.append(cluster_name)
        cell_name_list.append(cell_id)
        entropy_list.append(entropy_name)
    df_value=pd.DataFrame({'cluster_name': cluster_name_list,'cell_name':cell_name_list,'entropy':entropy_list})
    adata.obs['entropy']=df_value['entropy'].values
    df_obs=adata.obs
    cluster_order=list(pd.DataFrame(df_obs[[obs_key,'entropy']].groupby([obs_key]).mean()).sort_values(['entropy'],ascending=False).index)
    df_entropy=pd.DataFrame(df_obs[[obs_key,'entropy']].groupby([obs_key]).mean()).sort_values(['entropy'],ascending=False)
    df_obs[obs_key]= pd.Categorical(df_obs[obs_key], categories=cluster_order, ordered=True)
    print('Cluster order sorted by entropy value: ',list(df_entropy.index))
    df_entropy.index=list(df_entropy.index)
    adata.uns['entropy value']=df_obs
    adata.uns['entropy value order']=df_entropy
    #display(df_entropy)
    return adata

# %%
adata=assess_start_cluster(adata, 'dmt_leiden_anno')
# Out:
# Cluster order sorted by entropy value:  ['ctx_sc_09', 'hip_sc_18', 'hip_sc_22', 'hip_sc_21', 'ctx_sc_07', 'ctx_sc_16', 'hip_sc_20', 'ctx_sc_11', 'hip_sc_23', 'ctx_sc_15', 'hip_sc_19', 'ctx_sc_03', 'ctx_sc_10', 'ctx_sc_12', 'ctx_sc_04', 'ctx_sc_08', 'ctx_sc_17', 'ctx_sc_02', 'ctx_sc_13', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_01', 'ctx_sc_14']

# %%
data = adata.uns['entropy value'].copy()
data = data[data['dmt_leiden_anno'].isin(['hip_sc_18', 'hip_sc_19'])]
data['dmt_leiden_anno'] = data['dmt_leiden_anno'].astype(str).astype('category')

# %%
1
# Out:
# 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator
plt.figure(figsize=(3, 4))

ax = sns.boxplot(
    data=data,
    x='dmt_leiden_anno',
    y='entropy',
    hue='stage',
    linewidth=0.8,
    # palette=colormap,  # 这里可以注释掉，因为我们手动管理颜色
    order=['hip_sc_18', 'hip_sc_19'],
    showfliers=False
)

ax.set_xticklabels(
    # adata.uns['entropy value order'].index.values,
    ['hip_sc_18', 'hip_sc_19'],
    rotation=40, ha='right'
)

ax.set_xlabel(' ')
ax.set_ylabel('Entropy Value')
ax.legend(frameon = False)

ax.set_xlabel(' ')
ax.set_ylabel('Entropy Value')
ax.legend(frameon=False)

pairs = [
    ('hip_sc_18', 'hip_sc_19')
]

annotator = Annotator(
    ax, pairs,
    data=data,
    x='dmt_leiden_anno',
    y='entropy',
    hue='dmt_leiden_anno',
    order=['hip_sc_18', 'hip_sc_19'],
)
annotator.configure(test='t-test_ind', text_format='star', loc='inside')  # 选择检验方法
annotator.apply_and_annotate()

plt.tight_layout()

plt.savefig('/data/work/05.cluster/FuseMap/0116/tracks/Entropy_main.pdf', bbox_inches = 'tight')
# plt.show()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# hip_sc_18 vs. hip_sc_19: t-test independent samples, P_val:4.408e-283 t=3.797e+01

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

ax = sns.violinplot(
    data=adata.uns['entropy value'],
    x='dmt_leiden_anno',
    y='entropy',
    hue='stage',
    linewidth=0.8,
    order=adata.uns['entropy value order'].index,
    split=True, inner="quart"
)

ax.set_xticklabels(
    adata.uns['entropy value order'].index.values,
    rotation=40, ha='right'
)

ax.set_xlabel(' ')
ax.set_ylabel('Entropy Value')
ax.legend(frameon = False, loc = 'lower left')

plt.tight_layout()

plt.savefig('/data/work/05.cluster/FuseMap/0116/tracks/Entropy_extend.pdf', bbox_inches = 'tight')

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # 创建画布
# plt.figure(figsize=(8, 5))
#
# # 绘制箱线图
# ax1 = sns.boxplot(
#     data=adata.uns['entropy value'],
#     x='dmt_leiden_anno',
#     y='entropy',
#     linewidth=0.8,
#     palette=colormap,
#     order=adata.uns['entropy value order'].index,
#     showfliers=False
# )
#
# # 叠加散点图，按 stage 区分颜色
# sns.stripplot(
#     data=adata.uns['entropy value'],
#     x='dmt_leiden_anno',
#     y='entropy',
#     hue='stage',
#     # palette=colormap,
#     dodge=True,  # 分组显示
#     size=3,  # 点的大小
#     alpha=0.7,  # 点的透明度
#     order=adata.uns['entropy value order'].index
# )
#
# # 设置 x 轴标签旋转
# ax1.set_xticklabels(
#     adata.uns['entropy value order'].index.values,
#     rotation=40, ha='right'
# )
#
# # 设置轴标签
# ax1.set_xlabel(' ')
# ax1.set_ylabel('Entropy Value')
#
# # 添加图例
# handles, labels = ax1.get_legend_handles_labels()
# ax1.legend(handles[-2:], labels[-2:],loc='upper right', bbox_to_anchor=(1.2, 1),title='Stage', frameon = False)  # 避免重复图例
#
# # 自动调整布局
# plt.tight_layout()
#
# # 显示图像
# # plt.show()
# plt.savefig('Entropy.pdf', bbox_inches = 'tight')

# %% [raw]
# plt.figure(figsize=(6,4))
# ax1=sns.boxplot(data=adata.uns['entropy value'],x='dmt_leiden_anno',y='entropy',linewidth=0.8,
#                 palette=colormap,
#                order=adata.uns['entropy value order'].index,showfliers=False)
# ax1.set_xticklabels(adata.uns['entropy value order'].index.values,
#                     rotation=40,ha='right',)
# ax1.set_xlabel(' ')
# ax1.set_ylabel('entropy value',)
# plt.tight_layout()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 84414 × 18392
#     obs: 'dnbCount', 'area', 'orig.ident', 'x', 'y', 'region', 'n_counts', 'region_h2', 'Tangram_1119_celltype', 'Tangram_1119_celltype_main_frac', 'region_hip', 'slice_code', 'sub_region', 'dmt_leiden', 'dmt_leiden_merge', 'dmt_leiden_anno', 'cluster_img_label', 'digital_layer', 'digital_column', 'stage', 'entropy'
#     uns: 'entropy value', 'entropy value order'
#     obsm: 'X_dmt', 'X_dmt_highdim', 'align_spatial_2d', 'align_spatial_3d', 'cell_border', 'latent_embeddings_all_single_pretrain', 'latent_embeddings_all_spatial_pretrain', 'spatial', 'spatial_division', 'spatial_new'

# %%
adata2.obs['cluster'] = adata2.obs['dmt_leiden_anno']
adata2.obsm['X_spatial'] = adata2.obsm['align_spatial_2d'].copy()
adata2.obsm['X_align_spatial_2d'] = adata2.obsm['align_spatial_2d'].copy()
adata2.obsm['X_pca'] = adata2.obsm['X_dmt_highdim'].copy()
start_cells = spt.set_start_cells(adata2, select_way='cell_type', cell_type='ctx_sc_17', )
adata2.obsp["trans"] = spt.get_ot_matrix(adata2, data_type="spatial",alpha1=0.3,alpha2=0.7)
adata2.obs["ptime"] = spt.get_ptime(adata2, start_cells)
adata2.obsm['X_align_spatial_2d'] = adata2.obsm['align_spatial_2d']
adata2.uns["E_grid"], adata2.uns["V_grid"] = spt.get_velocity(adata2, basis="align_spatial_2d", n_neigh_pos=100,n_neigh_gene=0)
# Out:
# The velocity of cells store in 'velocity_align_spatial_2d'.

# %%
sc.pl.violin(adata2, keys = 'ptime', groupby = 'dmt_leiden_anno',rotation = 45)

# %%
adata1.obs['cluster'] = adata1.obs['dmt_leiden_anno'].copy()
adata1.obsm['X_spatial'] = adata1.obsm['align_spatial_2d'].copy()
adata1.obsm['X_align_spatial_2d'] = adata1.obsm['align_spatial_2d'].copy()
adata1.obsm['X_pca'] = adata1.obsm['X_dmt_highdim'].copy()
start_cells = spt.set_start_cells(adata1, select_way='cell_type', cell_type='ctx_sc_17', )
adata1.obsp["trans"] = spt.get_ot_matrix(adata1, data_type="spatial",alpha1=0.3,alpha2=0.7)
adata1.obs["ptime"] = spt.get_ptime(adata1, start_cells)
adata1.uns["E_grid"], adata1.uns["V_grid"] = spt.get_velocity(adata1, basis="align_spatial_2d", n_neigh_pos=100,n_neigh_gene=0)

# %%
sc.pl.violin(adata1, keys = 'ptime', groupby = 'dmt_leiden_anno',rotation = 45)

# %%
adata_new = ad.concat([adata1, adata2])

# %%
plot = sc.pl.embedding(adata_new, basis = 'X_dmt',color = 'ptime', show = False, title = 'Pseudo Time'); 
plot.set_aspect('equal')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/dmt_ptime.png', bbox_inches = 'tight', dpi = 600)

# %%
plot = sc.pl.embedding(adata_new, basis = 'X_dmt',color = 'ptime', show = False, title = 'Pseudo Time', cmap = 'RdBu_r'); 
plot.set_aspect('equal')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/dmt_ptime_RdBu_r.png', bbox_inches = 'tight', dpi = 600)

# %%
plot = sc.pl.embedding(adata_new, basis = 'X_dmt',color = 'ptime', show = False, title = 'Pseudo Time', cmap = 'Reds'); 
plot.set_aspect('equal')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/dmt_ptime_Reds.png', bbox_inches = 'tight', dpi = 600)

# %%
1

# %%
1

# %%
1
# Out:
# 1

# %%
adata

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

ax = sns.violinplot(
    data=adata_new.obs,
    x='dmt_leiden_anno',
    y='ptime',
    hue='stage',
    linewidth=0.8,
    order = ['ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 
     'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 
     'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'],
    # order=adata.uns['entropy value order'].index,
    split=True, inner="quart"
)

ax.set_xticklabels(
    ['ctx_sc_01', 'ctx_sc_02', 'ctx_sc_03', 'ctx_sc_04', 'ctx_sc_05', 'ctx_sc_06', 'ctx_sc_07', 'ctx_sc_08', 'ctx_sc_09', 
     'ctx_sc_10', 'ctx_sc_11', 'ctx_sc_12', 'ctx_sc_13', 'ctx_sc_14', 'ctx_sc_15', 'ctx_sc_16', 'ctx_sc_17', 
     'hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23'],
    rotation=40, ha='right'
)

ax.set_xlabel(' ')
ax.set_ylabel('Pseudo Time')
ax.legend(frameon = False, loc = 'lower left')

plt.tight_layout()

plt.savefig('/data/work/05.cluster/FuseMap/0116/tracks/Pseudo_Time_extend.pdf', bbox_inches = 'tight')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator
plt.figure(figsize=(3, 4))

ax = sns.boxplot(
    data=adata_new.obs,
    x='dmt_leiden_anno',
    y='ptime',
    hue='stage',
    linewidth=0.8,
    # palette=colormap,  # 这里可以注释掉，因为我们手动管理颜色
    order=['hip_sc_18', 'hip_sc_19',],
    showfliers=False
)

ax.set_xticklabels(
    # adata.uns['entropy value order'].index.values,
    ['hip_sc_18', 'hip_sc_19',],
    rotation=40, ha='right'
)

ax.set_xlabel(' ')
ax.set_ylabel('Pseudo Time')
ax.legend(frameon=False)

pairs = [
    ('hip_sc_18', 'hip_sc_19')
]

annotator = Annotator(
    ax, pairs,
    data=adata_new.obs,
    x='dmt_leiden_anno',
    y='ptime',
    hue='dmt_leiden_anno',
    order=['hip_sc_18', 'hip_sc_19'],
)
annotator.configure(test='t-test_ind', text_format='star', loc='inside')  # 选择检验方法
annotator.apply_and_annotate()

plt.tight_layout()

plt.savefig('/data/work/05.cluster/FuseMap/0116/tracks/Pseudo_Time_main.pdf', bbox_inches = 'tight')
# plt.show()
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# hip_sc_18 vs. hip_sc_19: t-test independent samples, P_val:2.099e-01 t=-1.254e+00

# %%
adata1

# %%
adata1.obsm['align_spatial_2d'][:, 1] = -adata1.obsm['align_spatial_2d'][:, 1]
adata2.obsm['align_spatial_2d'][:, 1] = -adata2.obsm['align_spatial_2d'][:, 1]

# %%
adata1.uns["E_grid"], adata1.uns["V_grid"] = spt.get_velocity(adata1, basis="align_spatial_2d", n_neigh_pos=100,n_neigh_gene=0)
adata2.uns["E_grid"], adata2.uns["V_grid"] = spt.get_velocity(adata2, basis="align_spatial_2d", n_neigh_pos=100,n_neigh_gene=0)

# %%
adata1.obsm['velocity_align_spatial_2d']

# %%
fig, axs = plt.subplots(figsize=(5, 5))
sc.pl.embedding(adata1, basis='align_spatial_2d',
                show=False,title='Pseudo Time',color='ptime',
                ax=axs,frameon=False,
                cmap = 'RdBu_r',
                legend_fontweight='normal',
                s = 1,
                projection = '2d',
               )
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/GW13_Ptime_spatialPlot.pdf')
plt.close()

# %%
fig, axs = plt.subplots(figsize=(5, 5))
sc.pl.embedding(adata2, basis='align_spatial_2d',
                show=False,title='Pseudo Time',color='ptime',
                ax=axs,frameon=False,
                cmap = 'RdBu_r',
                legend_fontweight='normal',
                s = 1,
               )
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/GW12_Ptime_spatialPlot.pdf')
plt.close()

# %%
fig, axs = plt.subplots(figsize=(5, 5))
sc.pl.embedding(adata2, basis='align_spatial_2d',
                show=False,title='Pseudo Time',color='dmt_leiden_anno',
                ax=axs,frameon=False,
                # cmap = 'RdBu_r',
                palette = colormap,
                legend_fontweight='normal',
                s = 1,
               )
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/GW12_celltype_spatialPlot.pdf')
plt.close()

# %%
fig, axs = plt.subplots(figsize=(5, 5))
sc.pl.embedding(adata1, basis='align_spatial_2d',
                show=False,title='Pseudo Time',color='dmt_leiden_anno',
                ax=axs,frameon=False,
                # cmap = 'RdBu_r',
                palette = colormap,
                legend_fontweight='normal',
                s = 1,
                projection = '2d',
               )
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/GW13_celltype_spatialPlot.pdf')
plt.close()

# %%
fig, axs = plt.subplots(figsize=(5, 5))
sc.pl.embedding(adata1, basis='align_spatial_2d',
                show=False,title='Pseudo Time',color='ptime',
                ax=axs,frameon=False,
                cmap = 'RdBu_r',
                legend_fontweight='normal',
                s = 1,
                projection = '2d',
               )
# axs.quiver(adata1.uns['E_grid'][0],adata1.uns['E_grid'][1],
#            adata1.uns['V_grid'][0],adata1.uns['V_grid'][1],
#            )
# axs.quiver(P_grid[0],P_grid[1],V_grid[0],V_grid[1],   C_grid, cmap = 'RdBu_r')
plt.savefig(f'/data/work/05.cluster/FuseMap/0116/tracks/GW13_Ptime_spatialPlot.pdf')
# plt.close()
