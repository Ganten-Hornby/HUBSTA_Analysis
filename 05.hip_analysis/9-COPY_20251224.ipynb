# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dic = {
    'hip_sc_1': 'hip_sc_18',
    'hip_sc_2': 'hip_sc_19',
    'hip_sc_3': 'hip_sc_20',
    'hip_sc_4': 'hip_sc_21',
    'hip_sc_5': 'hip_sc_22',
    'hip_sc_6': 'ctx_sc_01',
    'hip_sc_7': 'ctx_sc_02',
    'hip_sc_8': 'ctx_sc_03',
    'hip_sc_9': 'ctx_sc_04',
    'hip_sc_10': 'ctx_sc_05',
    'hip_sc_11': 'ctx_sc_06',
    'hip_sc_12': 'ctx_sc_07',
    'hip_sc_13': 'ctx_sc_08',
    'hip_sc_14': 'ctx_sc_09',
    'hip_sc_15': 'ctx_sc_10',
    'hip_sc_16': 'ctx_sc_11',
    'hip_sc_17': 'ctx_sc_12',
    'hip_sc_18': 'ctx_sc_13',
    'hip_sc_19': 'ctx_sc_14',
    'hip_sc_20': 'ctx_sc_15',
    'hip_sc_21': 'ctx_sc_16',
    'hip_sc_22': 'hip_sc_23',
    'hip_sc_23': 'ctx_sc_17',
}

# %%
sel = ['hip_sc_18', 'hip_sc_19', 'hip_sc_20', 'hip_sc_21', 'hip_sc_22', 'hip_sc_23']

# %%
for i in [
 #    '43_A03590E1G4_WT202403310064',
 # 'B03607C4E6_WT2024071214941',
 #    '12_B03605F3G5_WT202403310048',
 #    '13_B03612A1C3_WT202403310056',
 #    '14_A03591A1C3_WT202403310045',
 #    '16_A03592A4C6_WT202403310044',
    '18_B03602C4D6_WT202405020031',
    # '20_B03606F3G5_WT202405020032',
    # '22_B03606C4E6_WT202403310050',
    # '23_B03609A4D6_WT202404150263',
    # '27_B03610C1E3_WT202403310051',
    # '31_B03619A1D3_WT202403310052',
    # '35_B03619E4G6_WT202403310053',
    # '39_A03589A1D4_WT202403310046',
    # '47_A03593C1F3_WT202403310068',
    
]:
    
    csv = pd.read_csv(f'/data/work/05.cluster/FuseMap/20250116/cci/{i}.csv', index_col = 'Unnamed: 0')
    # csv = csv[csv['lr_pair'].isin([
    #     'NTS-NTSR1',
    #     'SEMA3C-NRP1',
    #     'SEMA3A-NRP1',
    #     'MIF-CXCR4',
    #     'NRXN1-NLGN1',
    #     'NRXN2-NLGN1'
    # ])]
    
    csv['sr_pair'] = [dic[i.split('-')[0]] + '-' + dic[i.split('-')[1]] for i in csv['sr_pair']]
    # csv['lr_pair'] = [dic[i.split('-')[0]] + '-' + dic[i.split('-')[1]] for i in csv['lr_pair']]
    csv['send'] = [i.split('-')[0] for i in csv['sr_pair']]
    csv['receive'] = [i.split('-')[1] for i in csv['sr_pair']]
    csv = csv[csv['send'].isin(sel) | csv['receive'].isin(sel)]
    # break
    plt.figure(figsize=(len(list(set(csv['sr_pair'])))/3, len(list(set(csv['lr_pair'])))/4+2))
    scaler = MinMaxScaler()
    csv['lr_co_exp_ratio_scaled'] = scaler.fit_transform(csv[['lr_co_exp_ratio']])
    sns.scatterplot(x='sr_pair', 
                    y='lr_pair', 
                    size='lr_co_exp_ratio', 
                    hue = 'lr_co_exp_ratio',
                    data=csv,
                    palette = 'viridis',
                    # legend=False  # 先关闭legend，稍后统一处理
                   )
    handles, labels = plt.gca().get_legend_handles_labels()
    labels = [f"{float(label):.2f}" for label in labels] 
    plt.legend(handles, labels, bbox_to_anchor=(1.05, 1), loc='upper left')
    significant_points = csv[csv['is_significant'] == True]
    plt.scatter(x=significant_points['sr_pair'], 
                y=significant_points['lr_pair'], 
                facecolors='none', 
                edgecolors='red', 
                s=100)  # 调整s参数以控制圆圈大小

    plt.xlim(-1, len(list(set(csv['sr_pair'])))+1)
    # plt.margins(y=0.1)  
    plt.xticks(rotation=45, ha = 'right')
    plt.xlabel(xlabel = None)
    plt.ylabel(ylabel = None)
    plt.title(f'')
    plt.tight_layout()
    plt.savefig(f'/data/work/05.cluster/hip_sp/hip_05/dot_plot.pdf', bbox_inches = 'tight')
    plt.close()
    # plt.show()
    # break

# %%
csv
# Out:
#         from     to   pathway                type       lr_pair  lr_product  \
# 2185     NTS  NTSR1       NTS  Secreted Signaling     NTS-NTSR1    0.018223
# 3766   LRRC4  NTNG2       NGL   Cell-Cell Contact   LRRC4-NTNG2    0.001458
# 2310  SEMA3C   NRP1     SEMA3  Secreted Signaling   SEMA3C-NRP1    0.092441
# 2286  SEMA3A   NRP1     SEMA3  Secreted Signaling   SEMA3A-NRP1    0.035131
# 3821  SEMA4A   NRP1     SEMA4   Cell-Cell Contact   SEMA4A-NRP1    0.004968
# ...      ...    ...       ...                 ...           ...         ...
# 3265  COL4A6  ITGB8  COLLAGEN        ECM-Receptor  COL4A6-ITGB8    0.013807
# 2589  COL4A6  ITGA2  COLLAGEN        ECM-Receptor  COL4A6-ITGA2    0.014793
# 2568  COL1A2  ITGA2  COLLAGEN        ECM-Receptor  COL1A2-ITGA2    0.004692
# 3265  COL4A6  ITGB8  COLLAGEN        ECM-Receptor  COL4A6-ITGB8    0.002737
# 1735     MIF  CXCR4       MIF  Secreted Signaling     MIF-CXCR4    0.002737
#
#       lr_co_exp_num  lr_co_exp_ratio  lr_co_exp_ratio_pvalue  is_significant  \
# 2185             57         0.004155                   0.000            True
# 3766              8         0.000583                   0.000            True
# 2310            115         0.020405                   0.000            True
# 2286             43         0.007630                   0.000            True
# 3821             14         0.002484                   0.000            True
# ...             ...              ...                     ...             ...
# 3265              7         0.006903                   0.000            True
# 2589              6         0.005917                   0.000            True
# 2568             15         0.002933                   0.000            True
# 3265              7         0.001369                   0.001            True
# 1735              6         0.001173                   0.154           False
#
#                   sr_pair       send    receive
# 2185  hip_sc_18-hip_sc_19  hip_sc_18  hip_sc_19
# 3766  hip_sc_18-hip_sc_19  hip_sc_18  hip_sc_19
# 2310  hip_sc_18-hip_sc_20  hip_sc_18  hip_sc_20
# 2286  hip_sc_18-hip_sc_20  hip_sc_18  hip_sc_20
# 3821  hip_sc_18-hip_sc_20  hip_sc_18  hip_sc_20
# ...                   ...        ...        ...
# 3265  ctx_sc_17-hip_sc_21  ctx_sc_17  hip_sc_21
# 2589  ctx_sc_17-hip_sc_21  ctx_sc_17  hip_sc_21
# 2568  ctx_sc_17-hip_sc_23  ctx_sc_17  hip_sc_23
# 3265  ctx_sc_17-hip_sc_23  ctx_sc_17  hip_sc_23
# 1735  ctx_sc_17-hip_sc_23  ctx_sc_17  hip_sc_23
#
# [122 rows x 13 columns]
