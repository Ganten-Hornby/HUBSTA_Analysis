# %%
# SC anno tation

# %%
import scanpy as sc
import anndata as ad
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from matplotlib.colors import ListedColormap, rgb2hex
import numpy as np
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.metrics import jaccard_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('/data/work/05.cluster/FuseMap/0106/thalamus_latent_embeddings_all_spatial_pretrain/dmt_leiden_20250108_1.h5ad')
adata.obs_names_make_unique()
adata
# Out:
# AnnData object with n_obs × n_vars = 3279854 × 33347
#     obs: 'dnbCount', 'area', 'orig.ident', 'x', 'y', 'region', 'n_counts', 'region_h2', 'slice_code', 'sub_region', 'dmt_leiden', 'annotation_1230', 'dmt_leiden_merge'
#     uns: 'dmt_leiden_colors', 'dmt_leiden_merge_colors', 'dmt_nn', 'leiden', 'slice_code_colors'
#     obsm: 'X_dmt', 'X_dmt_highdim', 'align_spatial_2d', 'align_spatial_3d', 'cell_border', 'latent_embeddings_all_single_pretrain', 'latent_embeddings_all_spatial_pretrain', 'spatial', 'spatial_division'
#     obsp: 'dmt_nn_connectivities', 'dmt_nn_distances'

# %%
adatas = []
for i in set(adata.obs['slice_code']):
    temp = adata[adata.obs['slice_code'] == i].copy()
    temp.write(f'/data/work/05.cluster/FuseMap/0117/tangram/{i}')

# %%
for i in set(adata.obs['slice_code']):
    print(f'python /data/work/05.cluster/FuseMap/0117/tangram_yes.py --sc_data_path /data/work/05.cluster/FuseMap/0117/second-tri-thalamus_norm.h5ad --sc_label clusters --st_data_path /data/work/05.cluster/FuseMap/0117/tangram_raw/{i} --output_path /data/work/05.cluster/FuseMap/0117/tangram_o/{i}')
# Out:
# python /data/work/05.cluster/FuseMap/0117/tangram_yes.py --sc_data_path /data/work/05.cluster/FuseMap/0117/second-tri-thalamus_norm.h5ad --sc_label clusters --st_data_path /data/work/05.cluster/FuseMap/0117/tangram_raw/51_B03605C2E5_WT202406020126.h5ad --output_path /data/work/05.cluster/FuseMap/0117/tangram_o/51_B03605C2E5_WT202406020126.h5ad
# python /data/work/05.cluster/FuseMap/0117/tangram_yes.py --sc_data_path /data/work/05.cluster/FuseMap/0117/second-tri-thalamus_norm.h5ad --sc_label clusters --st_data_path /data/work/05.cluster/FuseMap/0117/tangram_raw/B03618D3F6_WT202407152793.h5ad --output_path /data/work/05.cluster/FuseMap/0117/tangram_o/B03618D3F6_WT202407152793.h5ad
# ...
