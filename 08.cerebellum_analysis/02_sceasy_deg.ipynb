# %%
library(presto)
library(sceasy)
library(reticulate)
library(Seurat)
library(tidyverse)

# sceasy::convertFormat('/data/work/05.cluster/FuseMap/20251103/1_deg/single.h5ad', 
#                       from="anndata", 
#                       to="seurat",
#                       outFile='/data/work/05.cluster/FuseMap/20251103/1_deg/single.rds')

rds = readRDS('/data/work/05.cluster/FuseMap/20251103/1_deg/single.rds')
csv = wilcoxauc(rds, 'dmt_leiden_anno')
write.table(csv, file = "/data/work/05.cluster/FuseMap/20251103/1_deg/single_deg.csv", sep = ",", row.names = FALSE)
# Out:
# Loading required package: Rcpp
#
# Loading required package: data.table
#
# Loading required package: reticulate
#
# Attaching SeuratObject
#
# Warning message in system("timedatectl", intern = TRUE):
# "running command 'timedatectl' had status 1"
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.4.0     v purrr   1.0.2
# v tibble  3.2.1     v dplyr   1.1.4
# v tidyr   1.3.1     v stringr 1.5.1
# v readr   2.1.3     v forcats 0.5.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::between()   masks data.table::between()
# x dplyr::filter()    masks stats::filter()
# x dplyr::first()     masks data.table::first()
# x dplyr::lag()       masks stats::lag()
# x dplyr::last()      masks data.table::last()
# x purrr::transpose() masks data.table::transpose()

# %% [raw]
# library(presto)
# library(sceasy)
# library(reticulate)
# library(Seurat)
# library(tidyverse)
#
# sceasy::convertFormat('/data/work/05.cluster/FuseMap/20251103/1_deg/spatial.h5ad',
#                       from="anndata",
#                       to="seurat",
#                       outFile='/data/work/05.cluster/FuseMap/20251103/1_deg/spatial.rds')
#
# rds = readRDS('/data/work/05.cluster/FuseMap/20251103/1_deg/spatial.rds')
# csv = wilcoxauc(rds, 'dmt_leiden_merge')
# write.table(csv, file = "/data/work/05.cluster/FuseMap/20251103/1_deg/spatial_deg.csv", sep = ",", row.names = FALSE)

# %%
1
# Out:
# [1] 1
