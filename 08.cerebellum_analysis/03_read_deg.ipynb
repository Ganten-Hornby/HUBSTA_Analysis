# %%
import pandas as pd

# %%
csv = pd.read_csv('/data/work/05.cluster/FuseMap/20251103/1_deg/spatial_deg.csv')
csv = csv[csv['logFC']>0.25]
csv.to_csv('/data/work/05.cluster/FuseMap/20251103/1_deg/spatial_deg_filter.csv')

# %%
csv
# Out:
#            feature   group   avgExpr     logFC     statistic       auc  pval  \
# 6006    AC092143.1  Cebe_0  0.962250  0.375196  3.471734e+10  0.606467   0.0
# 14755        BASP1  Cebe_0  0.814656  0.282413  3.341972e+10  0.583800   0.0
# 16130        CELF4  Cebe_0  0.491570  0.295828  3.153088e+10  0.550804   0.0
# 18544       ELAVL4  Cebe_0  0.449878  0.282230  3.113279e+10  0.543850   0.0
# 18845        ESRRG  Cebe_0  0.448729  0.286347  3.107478e+10  0.542836   0.0
# ...            ...     ...       ...       ...           ...       ...   ...
# 446556      PTGER3  Cebe_9  0.374202  0.262220  3.420050e+10  0.527446   0.0
# 448003        RORA  Cebe_9  0.840515  0.489817  3.862957e+10  0.595752   0.0
# 449563      SLC1A6  Cebe_9  0.526058  0.284595  3.514966e+10  0.542084   0.0
# 450397        SOX4  Cebe_9  0.949456  0.339713  3.754052e+10  0.578957   0.0
# 453615       WNT7B  Cebe_9  0.441432  0.272382  3.469534e+10  0.535078   0.0
#
#         padj     pct_in    pct_out
# ...

# %%
csv = pd.read_csv('/data/work/05.cluster/FuseMap/20251103/1_deg/single_deg.csv')
csv = csv[csv['logFC']>0.25]
csv.to_csv('/data/work/05.cluster/FuseMap/20251103/1_deg/single_deg_filter.csv')
